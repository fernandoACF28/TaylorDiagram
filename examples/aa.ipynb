# %%
from Taylor import *
obsSTD = 0.35
s = [0.33, 0.34, 0.36, 0.38]
r = [0.7,-0.1, 0.81, 0.58]
l = ['A', 'B', 'C', 'D']

PlotTaylorDiagram(obsSTD=obsSTD,
                       std_val_model=s, 
                       r_values=r, 
                       name_models=l,
                       savefig=False,
                       positive_only=False,
                       font_params={'font_family':'georgia'},
                       title='Taylor Diagram - Correlation Analysis'
                       )
